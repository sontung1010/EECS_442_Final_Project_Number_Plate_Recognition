# %% [markdown]
# # License Plate Detection using YOLOv3
# YOLO abbreviates to You Only Look Once depicting its ability to detect objects and entities by using CNN (Convolutional Neural Network).Neural Network in YOLO uses weights trained by the user through annotated training data by using bounding boxes. Hence YOLO takes an image as input puts it through a Neural Network and gives the output in the image through bounding boxes.

# %% [markdown]
# ## Importing necessary libraries

# %%
from google.colab import drive
drive.mount('/content/drive')

# dependencies
# NumPy versions below 1.17 may be incompatible with some other
# packages, so you may need to replace your current version with
# an earlier one in order to run this notebook as-is.
# !pip uninstall numpy --yes
# !pip install "numpy<1.17"
#pip install ipython
#pip install matplotlib
#pip install opencv-python
#pip install argparse


from IPython.display import Image
from matplotlib import pyplot as plt

import cv2
import argparse
import sys
import numpy as np
import pandas as pd
import os.path

import imutils
import math

from keras.layers import Flatten, Dense, Conv2D, MaxPooling2D, Input, Dropout
from keras.models import Model, Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### If you want to test your own image , simply add the path of the image in the input_path variable, add 'r' before the path so it will be treated as raw string
# #### For Example: input_path = r'path_to_image_folder/image.jpg'

# %%
#Enter path for the image to be tested
input_path = r'/content/drive/MyDrive/EECS442/project/kaggle_data/plate_datasets/Kaggle_dataset/images/Cars401.png'

# %%
Image(input_path)

# %% [markdown]
# ## Input Receiver

# %%
#Open the image file
cap = cv2.VideoCapture(input_path)

# %% [markdown]
# ## YOLO Plate Detection
# ### Initialize the parameters

# %%
# Initialize the parameters

confThreshold = 0.5  #Confidence threshold
nmsThreshold = 0.4  #Non-maximum suppression threshold

inpWidth = 416     #Width of network's input image
inpHeight = 416     #Height of network's input image

# %% [markdown]
# #### Access classes.names file from: https://github.com/pragatiunna/License-Plate-Number-Detection/tree/main/yolo_utils

# %%
# Load names of classes
classesFile = "/content/drive/MyDrive/EECS442/project/kaggle_data/yolo_utils/classes.names";

# %%
# Append all different classes into the list 'classes'
classes = None
with open(classesFile, 'rt') as f:
    classes = f.read().rstrip('\n').split('\n')

# %% [markdown]
# ### Restore the neural network
# #### Find the YOLO configuration file here: https://github.com/pragatiunna/License-Plate-Number-Detection/tree/main/yolo_utils
# #### Find the model weights here: https://drive.google.com/file/d/1cktcL1TXXRJ5o6CxzIuR08hPEWbb8Kkx/view?usp=sharing

# %%
# Give the configuration and weight files for the model and load the network using them.
modelConfiguration = r"/content/drive/MyDrive/EECS442/project/kaggle_data/yolo_utils/darknet-yolov3.cfg";
modelWeights = r"/content/drive/MyDrive/EECS442/project/kaggle_data/yolo_utils/lapi.weights";

# %% [markdown]
# After importing the config and weights file, set up the model using ```cv2.dnn.readNetFromDarknet()``` function.

# %%
net = cv2.dnn.readNetFromDarknet(modelConfiguration, modelWeights)
net.setPreferableBackend(cv2.dnn.DNN_BACKEND_OPENCV)
net.setPreferableTarget(cv2.dnn.DNN_TARGET_CPU)

# %% [markdown]
# ### Define the post processing functions

# %%
# Get the names of the output layers
def getOutputsNames(net):
    # Get the names of all the layers in the network
    layersNames = net.getLayerNames()
    # Get the names of the output layers, i.e. the layers with unconnected outputs

    return [layersNames[i - 1] for i in net.getUnconnectedOutLayers()]
    #print(layersNames)
    #print(net.getUnconnectedOutLayers())
    #return [layersNames[i[0] - 1] for i in net.getUnconnectedOutLayers()]

# %% [markdown]
# The following function ```drawPred()``` draws a bounding box in an image when attributes like class name, confidence, coordinates and the image itself is passed though it.

# %%
# Draw the predicted bounding box
def drawPred(classId, conf, left, top, right, bottom, frame):
    # Draw a bounding box.
    cv2.rectangle(frame, (left, top), (right, bottom), (0, 255, 0), 3)

    label = '%.2f' % conf

    # Get the label for the class name and its confidence
    if classes:
        assert(classId < len(classes))
        label = '%s:%s' % (classes[classId], label)

    #Display the label at the top of the bounding box
    labelSize, baseLine = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.5, 1)
    top = max(top, labelSize[1])
    cv2.rectangle(frame, (left, top - round(1.5*labelSize[1])), (left + round(1.5*labelSize[0]), top + baseLine), (0, 0, 255), cv2.FILLED)
    #cv.rectangle(frame, (left, top - round(1.5*labelSize[1])), (left + round(1.5*labelSize[0]), top + baseLine),    (255, 255, 255), cv.FILLED)
    cv2.putText(frame, label, (left, top), cv2.FONT_HERSHEY_SIMPLEX, 0.75, (0,0,0), 2)

# %% [markdown]
# The following function ```postprocess()``` removes the bounding boxes with low confidence when the image and ouput are passed as attributes.

# %%
# Remove the bounding boxes with low confidence using non-maxima suppression
def postprocess(frame, outs):
    frameHeight = frame.shape[0]
    frameWidth = frame.shape[1]

    # Scan through all the bounding boxes output from the network and keep only the
    # ones with high confidence scores. Assign the box's class label as the class with the highest score.
    classIds = []
    confidences = []
    boxes = []
    for out in outs:
        #print("out.shape : ", out.shape)
        for detection in out:
            #if detection[4]>0.001:
            scores = detection[5:]
            classId = np.argmax(scores)
            #if scores[classId]>confThreshold:
            confidence = scores[classId]
            '''if detection[4]>confThreshold:
                print(detection[4], " - ", scores[classId], " - th : ", confThreshold)
                print(detection)'''
            if confidence > confThreshold:
                center_x = int(detection[0] * frameWidth)
                center_y = int(detection[1] * frameHeight)
                width = int(detection[2] * frameWidth)
                height = int(detection[3] * frameHeight)
                left = int(center_x - width / 2)
                top = int(center_y - height / 2)
                classIds.append(classId)
                confidences.append(float(confidence))
                boxes.append([left, top, width, height])

    # Perform non maximum suppression to eliminate redundant overlapping boxes with lower confidences.
    cropped=None
    indices = cv2.dnn.NMSBoxes(boxes, confidences, confThreshold, nmsThreshold)
    #print("INDICES")
    #print(indices)
    for i in indices:
        #i = i[0]
        box = boxes[i]
        left = box[0]
        top = box[1]
        width = box[2]
        height = box[3]

        # calculate bottom and right
        bottom = top + height
        right = left + width

        #crop the plate out
        cropped = frame[top:bottom, left:right].copy()
        # drawPred
        drawPred(classIds[i], confidences[i], left, top, right, bottom, frame)
    if cropped is not None:
        return cropped

# %% [markdown]
# ### Plate Detection
# The following code snippet first creates a 4D blob from the image, sets input to the network, runs the forward pass to get output of the output layers and sends the image to the function ```postprocess()``` for removing low confidence boxes and drawing the predicted box.

# %%
cap = cv2.VideoCapture(input_path)
while cv2.waitKey(1) < 0:
    hasFrame, frame = cap.read() #frame: an image object from cv2
    ''' print(hasFrame)
    print(frame)
    print(frame.shape)
    print(cap)
    Image(frame)'''
    # Stop the program if reached end of video
    if not hasFrame:
        print("Done processing !!!")
        break

    # Create a 4D blob from a frame.
    blob = cv2.dnn.blobFromImage(frame, 1/255, (inpWidth, inpHeight), [0,0,0], 1, crop=False)

    # Sets the input to the network
    net.setInput(blob)

    # Runs the forward pass to get output of the output layers
    outs = net.forward(getOutputsNames(net))

    # Remove the bounding boxes with low confidence
    cropped = postprocess(frame, outs)

    plt.imshow(frame)
    plt.title("Predicted License Plate")
    plt.show()
    plt.imshow(cropped)
    plt.title("Cropped Image")
    plt.show()
# Out:
# Done processing !!!

# %% [markdown]
# ## Character Segmentation
# Character segmentation is an operation that seeks to decompose an image of a sequence of characters into subimages of individual symbols. It is one of the decision processes in a system for optical character recognition (OCR).
#
# This phase contains the use of two functions: ```segment_characters()``` and ```find_contours()```.

# %%
# Match contours to license plate or character template
def find_contours(dimensions, img) :

    # Find all contours in the image
    #cntrs, _ = cv2.findContours(img.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)#(img.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    # Apply Laplacian to get the gradients
    laplacian = cv2.Laplacian(img, cv2.CV_64F)
    laplacian = np.uint8(np.absolute(laplacian))

    # Find all contours in the gradient image
    cntrs, _ = cv2.findContours(laplacian.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    '''print('CNTRS LEN')
    print(len(cntrs))

    plt.imshow(img, cmap='gray')
    plt.title('WITHIN find_contours')
    plt.show()'''

    # Retrieve potential dimensions
    lower_width = dimensions[0]
    upper_width = dimensions[1]
    lower_height = dimensions[2]
    upper_height = dimensions[3]

    # Check largest 5 or  15 contours for license plate or character respectively
    cntrs = sorted(cntrs, key=cv2.contourArea, reverse=True)[:15]

    ii = cv2.imread('contour.jpg')

    x_cntr_list = []
    target_contours = []
    img_res = []
    for cntr in cntrs :
        # detects contour in binary image and returns the coordinates of rectangle enclosing it
        intX, intY, intWidth, intHeight = cv2.boundingRect(cntr)

        # checking the dimensions of the contour to filter out the characters by contour's size
        if intWidth > lower_width and intWidth < upper_width and intHeight > lower_height and intHeight < upper_height :
            x_cntr_list.append(intX) #stores the x coordinate of the character's contour, to used later for indexing the contours

            char_copy = np.zeros((44,24))
            # extracting each character using the enclosing rectangle's coordinates.
            char = img[intY:intY+intHeight, intX:intX+intWidth]
            char = cv2.resize(char, (20, 40))

            '''cv2.rectangle(ii, (intX,intY), (intWidth+intX, intY+intHeight), (50,21,200), 2)
            plt.imshow(ii, cmap='gray')
            plt.title('Predict Segments')'''

            # Make result formatted for classification: invert colors
            #EEEEEEEEEEEEEEEEEEEEEEEE
            #char = cv2.subtract(255, char)

            # Resize the image to 24x44 with black border
            #EEEEEEEEEEEEEEEEEEEEEEEE
            char_copy[2:42, 2:22] = char
            char_copy[0:2, :] = 0
            char_copy[:, 0:2] = 0
            char_copy[42:44, :] = 0
            char_copy[:, 22:24] = 0

            img_res.append(char_copy) # List that stores the character's binary image (unsorted)
            #print('LEN UPDATE ' + str(len(img_res)))

    # Return characters on ascending order with respect to the x-coordinate (most-left character first)

    plt.show()
    # arbitrary function that stores sorted list of character indeces
    indices = sorted(range(len(x_cntr_list)), key=lambda k: x_cntr_list[k])
    img_res_copy = []
    for idx in indices:
        img_res_copy.append(img_res[idx])# stores character images according to their index
    img_res = np.array(img_res_copy)

    return img_res

# %% [markdown]
# In the above function, we will be applying some more image processing to extract the individual characters from the license plate. The steps involved will be:
# - Finding all the contours in the input image. The function cv2.findContours returns all the contours it finds in the image.
# - After finding all the contours we consider them one by one and calculate the dimension of their respective bounding rectangle. Now consider bounding rectangle is the smallest rectangle possible that contains the contour. All we need to do is do some parameter tuning and filter out the required rectangle containing required characters. For this, we will be performing some dimension comparison by accepting only those rectangle that have:
#   1. Width in the range 0, (length of the pic)/(number of characters) and,
#   2. Length in a range of (width of the pic)/2, 4*(width of the pic)/5. After this step, we should have all the characters extracted as binary images.

# %%
# Find characters in the resulting images
def segment_characters(image) :

    # Preprocess cropped license plate image
    img_lp = cv2.resize(image, (333, 75))
    img_gray_lp = cv2.cvtColor(img_lp, cv2.COLOR_BGR2GRAY)

    '''plt.imshow(img_gray_lp, cmap='gray')
    plt.title('gray')
    plt.show()'''

    _, img_binary_lp = cv2.threshold(img_gray_lp, 200, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)

    edges = cv2.Canny(img_binary_lp, 30, 150)
    '''plt.imshow(edges, cmap='gray')
    plt.title('EDGES')
    plt.show()'''

    '''
    img_binary_lp = cv2.erode(img_binary_lp, (3,3))

    plt.imshow(img_binary_lp, cmap='gray')
    plt.title('erode')
    plt.show()

    img_binary_lp = cv2.dilate(img_binary_lp, (3,3))

    plt.imshow(img_binary_lp, cmap='gray')
    plt.title('dialate')
    plt.show()'''

    LP_WIDTH = img_binary_lp.shape[0]
    LP_HEIGHT = img_binary_lp.shape[1]

    # Make borders white
    img_binary_lp[0:1,:] = 255
    img_binary_lp[:,0:1] = 255
    img_binary_lp[74:75,:] = 255
    img_binary_lp[:,332:333] = 255

    # Estimations of character contours sizes of cropped license plates
    dimensions = [LP_WIDTH/6,
                       LP_WIDTH/2,
                       LP_HEIGHT/10,
                       2*LP_HEIGHT/3]
    '''plt.imshow(img_binary_lp, cmap='gray')
    plt.title('Contour')
    plt.show()
    cv2.imwrite('contour.jpg',img_binary_lp)'''

    # Get contours within cropped license plate
    char_list = find_contours(dimensions, edges)#img_binary_lp)

    return char_list

# %% [markdown]
# The above function takes in the image as input and performs the following operation on it:
# - Resizes it to a dimension such that all characters seem distinct and clear.
# - Convert the colored image to a gray scaled image. We do this to prepare the image for the next process.
# - Now the threshold function converts the grey scaled image to a binary image i.e each pixel will now have a value of 0 or 1 where 0 corresponds to black and 1 corresponds to white. It is done by applying a threshold that has a value between 0 and 255, here the value is 200 which means in the grayscaled image for pixels having a value above 200, in the new binary image that pixel will be given a value of 1. And for pixels having value below 200, in the new binary image that pixel will be given a value of 0.
# - The image is now in binary form and ready for the next process Eroding. Eroding is a simple process used for removing unwanted pixels from the object’s boundary meaning pixels that should have a value of 0 but are having a value of 1.
# - The image is now clean and free of boundary noise, we will now dilate the image to fill up the absent pixels meaning pixels that should have a value of 1 but are having value 0.
# - The next step now is to make the boundaries of the image white. This is to remove any out of the frame pixel in case it is present.
# - Next, we define a list of dimensions that contains 4 values with which we’ll be comparing the character’s dimensions for filtering out the required characters.
# - Through the above processes, we have reduced our image to a processed binary image and we are ready to pass this image for character extraction.

# %%
char=segment_characters(cropped)

# %%
for i in range(len(char)):
    plt.subplot(1, len(char), i+1)
    plt.imshow(char[i], cmap='gray')
    plt.axis('off')
plt.show()

# %% [markdown]
# ## Character Recognition using CNN
# This phase has already been shown elaborately in this notebook: [1. License Plate Detection (using Contours)](https://github.com/pragatiunna/License-Plate-Number-Detection/blob/main/1.%20License%20Plate%20Detection%20(using%20Contours).ipynb). Please refer to this notebook first for understanding the implementation of the whole CNN model.
#
# We'll now simply create an instance of the model and then import the saved weights.

# %%
# Create a new model instance
loaded_model = Sequential()
loaded_model.add(Conv2D(32, (3,3), input_shape=(28, 28, 3), activation='relu', padding='same'))
loaded_model.add(MaxPooling2D(pool_size=(2, 2)))
loaded_model.add(Conv2D(32, (3,3), input_shape=(14, 14, 32), activation='relu', padding='same'))
loaded_model.add(MaxPooling2D(pool_size=(2, 2)))
loaded_model.add(Flatten())
loaded_model.add(Dense(512, activation='relu'))
loaded_model.add(Dense(36, activation='softmax'))

'''loaded_model.add(Conv2D(16, (22,22), input_shape=(28, 28, 3), activation='relu', padding='same'))
loaded_model.add(Conv2D(32, (16,16), input_shape=(28, 28, 3), activation='relu', padding='same'))
loaded_model.add(Conv2D(64, (8,8), input_shape=(28, 28, 3), activation='relu', padding='same'))
loaded_model.add(Conv2D(64, (4,4), input_shape=(28, 28, 3), activation='relu', padding='same'))
loaded_model.add(MaxPooling2D(pool_size=(4, 4)))
loaded_model.add(Dropout(0.4))
loaded_model.add(Flatten())
loaded_model.add(Dense(128, activation='relu'))
loaded_model.add(Dense(36, activation='softmax'))'''

# Restore the weights
loaded_model.load_weights('/content/drive/MyDrive/EECS442/project/checkpoints/TRIAL_Orig_weights.weights.h5')#('/content/drive/MyDrive/EECS442/project/checkpoints/my_checkpoint.weights.h5')

# %% [markdown]
# ## Predict the license plate number
# We now have our license plate and the CNN model ready! We just need to predict each character using the model. For this, we'll first fix the dimension of each character image using the function ```fix_dimension```, in which it converts an image to a 3-channel image. The image can then be sent to ```model.predict_classes()``` in order to get the predicted character.

# %%
# Define a function to apply edge detection to an image
def Gradient_detect(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray = cv2.normalize(gray, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
    gray = np.uint8(255 * gray)

    #IMPLEMENTAION USING CANNY EDGES
    '''plt.imshow(gray)
    plt.title('GRAY')
    plt.show()

    edges = cv2.Canny(gray, 30, 150)
    edges = edges.astype(np.float64) / 255

    plt.imshow(edges)
    plt.title('Edges')
    plt.show()

    edges = np.dstack([edges, edges, edges])
    #print('OUTPUT SHAPE ' + str(edges.shape))'''

    #IMPLEMENTATION USING LAP GRAD
    laplacian = abs(cv2.Laplacian(gray,cv2.CV_64F))
    laplacian = laplacian.astype(np.float64) / 255
    lap = np.dstack([laplacian, laplacian, laplacian])


    return lap


# Predicting the output
def fix_dimension(img):
    new_img = np.zeros((28,28,3))
    for i in range(3):
        new_img[:,:,i] = img
        return new_img

def show_results():
    dic = {}
    characters = '0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    for i,c in enumerate(characters):
        dic[i] = c

    output = []
    for i,ch in enumerate(char): #iterating over the characters
        img_ = cv2.resize(ch, (28,28), interpolation=cv2.INTER_AREA)
        img = fix_dimension(img_)


        img = img.reshape(28,28,3) #preparing image for the model

        # y_ = loaded_model.predict_classes(img)[0] #predicting the class
        #print(img.shape)
        #print(img)
        #print('TYPE', img.dtype)

        grad = Gradient_detect(img.astype(np.float32))

        grad = img.reshape(1,28,28,3)

        predictions = loaded_model.predict(grad)

        y_ = np.argmax(predictions, axis=1)[0]

        character = dic[y_]
        output.append(character) #storing the result in a list

    plate_number = ''.join(output)

    return plate_number

print(show_results())
# Out:
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 23ms/step
# KE

# %%
# Segmented characters and their predicted value.
plt.figure(figsize=(10,6))
for i,ch in enumerate(char):
    img = cv2.resize(ch, (28,28), interpolation=cv2.INTER_AREA)
    plt.subplot(3,4,i+1)
    plt.imshow(img,cmap='gray')
    plt.title(f'predicted: {show_results()[i]}')
    plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step

# %% [markdown]
# ## Importing the dataset
# We'll now import our dataset to calculate the overall accuracy of this method. The dataset contains about 200 images with a labels.xlsx that will be useful to check if the predicted output is correct.

# %%
labels=pd.read_excel('/content/drive/MyDrive/EECS442/project/kaggle_data/plate_datasets/Kaggle_dataset/Kaggle_labels.xlsx')
labels['ID']=labels['ID'].map(str)
labels
# Out:
#       ID      NUMBER
# 0      0  KLG1CA2555
# 1      1     PGMN112
# 2      2     PREANUP
# 3      3     DZ17YXR
# 4      4     PUI8BES
# ..   ...         ...
# 428  428      DZ1YXR
# 429  429      KA1SER
# 430  430      BCG986
# 431  431      KLBOSS
# 432  432    DL49AK49
#
# [433 rows x 2 columns]

# %%
file_list=os.listdir(r"/content/drive/MyDrive/EECS442/project/kaggle_data/plate_datasets/Kaggle_dataset/images")
# Define a function to extract the number from the filename
def extract_number(filename):
    return int(filename.replace('Cars', '').replace('.png', ''))

# Sort files numerically based on the extracted number
sorted_files = sorted(file_list, key=extract_number)

# %% [markdown]
# ## Accuracy
# We now need to run the whole code for all the images and calculate the accuracy.

# %%
file_list=os.listdir(r"/content/drive/MyDrive/EECS442/project/kaggle_data/plate_datasets/Kaggle_dataset/images")

# SHORTER LIST FOR TESTING
file_list = file_list[:70]

def extract_number(filename):
    return int(filename.replace('Cars', '').replace('.png', ''))
count = 0
dataset_error = 0

for path in sorted_files:
#for entry in labels['ID']:
    input_path = '/content/drive/MyDrive/EECS442/project/kaggle_data/plate_datasets/Kaggle_dataset/images/'+path
    is_video = False
    no = path.replace('Cars', '').replace('.png', '')
    # print("no = ", no)
    filtered_numbers = labels['NUMBER'].where(labels['ID'] == no).dropna().values
    # print("filtered_numbers = ", filtered_numbers)
    # print("size = ", filtered_numbers.size)

    # while cv2.waitKey(1) < 0:
    if filtered_numbers.size > 0:
        # cap = cv2.VideoCapture(input_path)
        frame = cv2.imread(input_path)
        if frame is None:
            print("Failed to read the image.")
            exit(1)

        outputFile = input_path + '_yolo_out_py.jpg'

        row=labels['NUMBER'].where(labels['ID'] == no).dropna().values[0]

        # get frame from the video
        # hasFrame, frame = cap.read() #frame: an image object from cv2


        # Stop the program if reached end of video
        # if not hasFrame:
        #     break

        # Create a 4D blob from a frame.
        try:
            blob = cv2.dnn.blobFromImage(frame, 1/255, (inpWidth, inpHeight), [0,0,0], 1, crop=False)
        except:
            break

        # Sets the input to the network
        net.setInput(blob)

        # Runs the forward pass to get output of the output layers
        outs = net.forward(getOutputsNames(net))

        # Remove the bounding boxes with low confidence
        cropped = postprocess(frame, outs)
        if cropped is not None and cropped.shape[1] > 0:
            # Put efficiency information. The function getPerfProfile returns the overall time for inference(t) and the timings for each of the layers(in layersTimes
            # print("Cropped image shape: ", cropped.shape)
            t, _ = net.getPerfProfile()
            label = 'Inference time: %.2f ms' % (t * 1000.0 / cv2.getTickFrequency())

            char=segment_characters(cropped)
            # Predicting the output
            plate = show_results()
            print("predicted number = ", plate)
            # print("row = ", row)
            for char in str(plate):
                if char in str(row):
                    count += 1/len(str(row))

        else:
            print("No license plate detected.")

            # plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
            # plt.title("Predicted License Plate")
            # plt.show()
            # if (str(plate) == str(row)):
            #     print('MATCHING')
            #     count += 1
            # else:
            #     print('WRONG')

        print("row = ", row)

    else:
        dataset_error += 1

    print("count = ", count)
    print("dataset_error = ", dataset_error)
    print("#####################################")
# Out:
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# predicted number =  MWSRS8EBMM5888
# row =  KLG1CA2555
# count =  0.1
# dataset_error =  0
# #####################################
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# predicted number =  PW8GEBMMRRR2M
# row =  PGMN112
# count =  0.9571428571428569
# dataset_error =  0
# #####################################
# No license plate detected.
# row =  PREANUP
# count =  0.9571428571428569
# dataset_error =  0
# #####################################
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# predicted number =  8WGEW8VWWWXX88
# row =  DZ17YXR
# count =  1.2428571428571424
# dataset_error =  0
# #####################################
# No license plate detected.
# row =  PUI8BES
# count =  1.2428571428571424
# dataset_error =  0
# #####################################
# No license plate detected.
# row =  DMKTI5
# count =  1.2428571428571424
# dataset_error =  0
# #####################################
# No license plate detected.
# row =  80211N
# count =  1.2428571428571424
# dataset_error =  0
# #####################################
# predicted number =
# row =  YSX213
# count =  1.2428571428571424
# dataset_error =  0
# #####################################
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# predicted number =  SMSM2MEMEXMMMMS
# row =  G526JHD
# count =  1.3857142857142852
# dataset_error =  0
# #####################################
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# predicted number =  S9M8MW8S8S88S
# row =  MHO1AV8866
# count =  2.085714285714286
# dataset_error =  0
# #####################################
# No license plate detected.
# row =  TN37CS2765
# count =  2.085714285714286
# dataset_error =  0
# #####################################
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# predicted number =  8MMSMK
# row =  WOR516K
# count =  2.2285714285714286
# dataset_error =  0
# #####################################
# No license plate detected.
# row =  MH12BG7237
# count =  2.2285714285714286
# dataset_error =  0
# #####################################
# No license plate detected.
# row =  BJR216
# count =  2.2285714285714286
# dataset_error =  0
# #####################################
# No license plate detected.
# row =  ALR486
# count =  2.2285714285714286
# dataset_error =  0
# #####################################
# predicted number =
# row =  TN21BY01266
# count =  2.2285714285714286
# dataset_error =  0
# #####################################
# count =  2.2285714285714286
# dataset_error =  1
# #####################################
# No license plate detected.
# row =  YSX213
# count =  2.2285714285714286
# dataset_error =  1
# #####################################
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# predicted number =  ESY8S
# row =  M666YOB
# count =  2.3714285714285714
# dataset_error =  1
# #####################################
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# predicted number =  PR288
# row =  AFR2011
# count =  2.657142857142857
# dataset_error =  1
# #####################################
# count =  2.657142857142857
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  1RQ
# count =  2.657142857142857
# dataset_error =  2
# #####################################
# 1/1 [==============================] - 0s 21ms/step
# predicted number =  S
# row =  YAMRAJ
# count =  2.657142857142857
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  9214
# count =  2.657142857142857
# dataset_error =  2
# #####################################
# predicted number =
# row =  HR26BC5514
# count =  2.657142857142857
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  BYHM136
# count =  2.657142857142857
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  M17108 FV1232
# count =  2.657142857142857
# dataset_error =  2
# #####################################
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# predicted number =  8WGEW8VWWWXX88
# row =  DZ17YXR
# count =  2.9428571428571426
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  AP11AM091
# count =  2.9428571428571426
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  9214
# count =  2.9428571428571426
# dataset_error =  2
# #####################################
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# predicted number =  88
# row =  SBA1234A SBV19665 JPK6546
# count =  2.9428571428571426
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  YD63LB
# count =  2.9428571428571426
# dataset_error =  2
# #####################################
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# predicted number =  Q8
# row =  MANISA
# count =  2.9428571428571426
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  0X65AWD
# count =  2.9428571428571426
# dataset_error =  2
# #####################################
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# predicted number =  EM2WSXMMW8RKW
# row =  DL7CN5617
# count =  2.9428571428571426
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  AK0188
# count =  2.9428571428571426
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  MIDLYPH
# count =  2.9428571428571426
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  FAST
# count =  2.9428571428571426
# dataset_error =  2
# #####################################
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# predicted number =  SMMR8B
# row =  OMGBCKY
# count =  3.371428571428571
# dataset_error =  2
# #####################################
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# predicted number =  88W5W8WW
# row =  MH15BD8877
# count =  3.7714285714285714
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  M17108 FV1232
# count =  3.7714285714285714
# dataset_error =  2
# #####################################
# predicted number =
# row =  YNTZDBG
# count =  3.7714285714285714
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  BYHM136
# count =  3.7714285714285714
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  MH20BQ20
# count =  3.7714285714285714
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  DL3CBF4907 DL2CAG0786
# count =  3.7714285714285714
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  IMGROOT
# count =  3.7714285714285714
# dataset_error =  2
# #####################################
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# predicted number =  8H2M3E8M
# row =  MH14GN9239
# count =  4.2714285714285705
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  5H798 5H799
# count =  4.2714285714285705
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  ALR486
# count =  4.2714285714285705
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  30461C
# count =  4.2714285714285705
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  PUI8BES
# count =  4.2714285714285705
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  YESBOSS
# count =  4.2714285714285705
# dataset_error =  2
# #####################################
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# predicted number =  88W5W8WW
# row =  MH15BD8877
# count =  4.671428571428569
# dataset_error =  2
# #####################################
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# predicted number =  SXMMGSXSX8MEK
# row =  CHIOOSE
# count =  5.242857142857142
# dataset_error =  2
# #####################################
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# predicted number =  LLYYWEEYY88
# row =  LTM378
# count =  5.90952380952381
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  9214
# count =  5.90952380952381
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  KLBOSS
# count =  5.90952380952381
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  BKWL324
# count =  5.90952380952381
# dataset_error =  2
# #####################################
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 67ms/step
# predicted number =  SKS8H86RMX8
# row =  MH01DB0001
# count =  6.109523809523809
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  MH46P1661
# count =  6.109523809523809
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  OS802HN
# count =  6.109523809523809
# dataset_error =  2
# #####################################
# predicted number =
# row =  MMN306
# count =  6.109523809523809
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  WATTUP
# count =  6.109523809523809
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  BIGTEAM
# count =  6.109523809523809
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  TAXI
# count =  6.109523809523809
# dataset_error =  2
# #####################################
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# predicted number =  SMX
# row =  ORINNIE
# count =  6.109523809523809
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  9214
# count =  6.109523809523809
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  MH14BN7077
# count =  6.109523809523809
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  BJR216
# count =  6.109523809523809
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  KWID
# count =  6.109523809523809
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  A156
# count =  6.109523809523809
# dataset_error =  2
# #####################################
# No license plate detected.
# row =  LNI3GJ2
# count =  6.109523809523809
# dataset_error =  2
# #####################################
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# predicted number =  EM2WSXMMW8RKW
# row =  DL7CN5617
# count =  6.109523809523809
# dataset_error =  2
# #####################################
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# predicted number =  YM88M8EP8
# row =  TN99F2378
# count =  6.553968253968252
# dataset_error =  2
# #####################################
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# predicted number =  SXM8VWMMM
# row =  CZ17K0D
# count =  6.553968253968252
# dataset_error =  2
# #####################################
# count =  6.553968253968252
# dataset_error =  3
# #####################################
# No license plate detected.
# row =  MH31EARSS
# count =  6.553968253968252
# dataset_error =  3
# #####################################
# predicted number =
# row =  HR26CU6799
# count =  6.553968253968252
# dataset_error =  3
# #####################################
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# predicted number =  MS88M48A8288V80
# row =  KL54A2670
# count =  6.998412698412695
# dataset_error =  3
# #####################################
# No license plate detected.
# row =  4GETOIL
# count =  6.998412698412695
# dataset_error =  3
# #####################################
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# predicted number =  BBMMRSEM8BR
# row =  BAD231
# count =  7.498412698412696
# dataset_error =  3
# #####################################
# No license plate detected.
# row =  ROY9
# count =  7.498412698412696
# dataset_error =  3
# #####################################
# No license plate detected.
# row =  UP16TC1366
# count =  7.498412698412696
# dataset_error =  3
# #####################################
# No license plate detected.
# row =  AU001
# count =  7.498412698412696
# dataset_error =  3
# #####################################
# predicted number =
# row =  HR26BC5514
# count =  7.498412698412696
# dataset_error =  3
# #####################################
# No license plate detected.
# row =  VU63GTY
# count =  7.498412698412696
# dataset_error =  3
# #####################################
# predicted number =
# row =  MH14DX9937
# count =  7.498412698412696
# dataset_error =  3
# #####################################
# No license plate detected.
# row =  TSLAS1
# count =  7.498412698412696
# dataset_error =  3
# #####################################
# predicted number =
# row =  2151
# count =  7.498412698412696
# dataset_error =  3
# #####################################
# No license plate detected.
# row =  SCORPIO
# count =  7.498412698412696
# dataset_error =  3
# #####################################
# count =  7.498412698412696
# dataset_error =  4
# #####################################
# No license plate detected.
# row =  30461C
# count =  7.498412698412696
# dataset_error =  4
# #####################################
# No license plate detected.
# row =  AD00008
# count =  7.498412698412696
# dataset_error =  4
# #####################################
# count =  7.498412698412696
# dataset_error =  5
# #####################################
# No license plate detected.
# row =  NBEYOND
# count =  7.498412698412696
# dataset_error =  5
# #####################################
# No license plate detected.
# row =  AD00008
# count =  7.498412698412696
# dataset_error =  5
# #####################################
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# predicted number =  PW8GEBMMRRR2M
# row =  PGMN112
# count =  8.355555555555553
# dataset_error =  5
# #####################################
# No license plate detected.
# row =  KA05MG1909
# count =  8.355555555555553
# dataset_error =  5
# #####################################
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# predicted number =  W8XGIEEW
# row =  YWORRY
# count =  8.688888888888885
# dataset_error =  5
# #####################################
# No license plate detected.
# row =  KA09MA2662
# count =  8.688888888888885
# dataset_error =  5
# #####################################
# No license plate detected.
# row =  WW95550
# count =  8.688888888888885
# dataset_error =  5
# #####################################
# predicted number =
# row =  HR26BC5514
# count =  8.688888888888885
# dataset_error =  5
# #####################################
# No license plate detected.
# row =  6861136
# count =  8.688888888888885
# dataset_error =  5
# #####################################
# count =  8.688888888888885
# dataset_error =  6
# #####################################
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# predicted number =  88LR8M8MSXX8M
# row =  NL60LXB
# count =  9.117460317460312
# dataset_error =  6
# #####################################
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# predicted number =  88
# row =  SBA1234A SBVJ9665 JPK6546
# count =  9.117460317460312
# dataset_error =  6
# #####################################
# No license plate detected.
# row =  GRAND
# count =  9.117460317460312
# dataset_error =  6
# #####################################
# No license plate detected.
# row =  MH20BQ20
# count =  9.117460317460312
# dataset_error =  6
# #####################################
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# predicted number =  S9M8MW8S8S88S
# row =  MH01AV8866
# count =  9.81746031746031
# dataset_error =  6
# #####################################
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# predicted number =  SXM8VWMMM
# row =  CZ17K0D
# count =  9.81746031746031
# dataset_error =  6
# #####################################
# No license plate detected.
# row =  F1
# count =  9.81746031746031
# dataset_error =  6
# #####################################
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# predicted number =  SM28EEV88
# row =  MH20EE7598
# count =  10.517460317460307
# dataset_error =  6
# #####################################
# predicted number =
# row =  SHAKNBK
# count =  10.517460317460307
# dataset_error =  6
# #####################################
# No license plate detected.
# row =  MPEACHW
# count =  10.517460317460307
# dataset_error =  6
# #####################################
# No license plate detected.
# row =  AP29BP585
# count =  10.517460317460307
# dataset_error =  6
# #####################################
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# predicted number =  ESY8S
# row =  M666YOB
# count =  10.660317460317449
# dataset_error =  6
# #####################################
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# predicted number =  RKRMMW
# row =  MK3532
# count =  11.160317460317447
# dataset_error =  6
# #####################################
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# predicted number =  R8SB
# row =  KA24MG3921
# count =  11.160317460317447
# dataset_error =  6
# #####################################
# No license plate detected.
# row =  JA62UAR
# count =  11.160317460317447
# dataset_error =  6
# #####################################
# count =  11.160317460317447
# dataset_error =  7
# #####################################
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# predicted number =  8M2E22288MMMK
# row =  B2228HM
# count =  12.731746031746013
# dataset_error =  7
# #####################################
# count =  12.731746031746013
# dataset_error =  8
# #####################################
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# predicted number =  Q8
# row =  MANISA
# count =  12.731746031746013
# dataset_error =  8
# #####################################
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# predicted number =  KR
# row =  HR26BC5514
# count =  12.831746031746013
# dataset_error =  8
# #####################################
# count =  12.831746031746013
# dataset_error =  9
# #####################################
# No license plate detected.
# row =  RP66887
# count =  12.831746031746013
# dataset_error =  9
# #####################################
# No license plate detected.
# row =  KA05MG1909
# count =  12.831746031746013
# dataset_error =  9
# #####################################
# No license plate detected.
# row =  S05
# count =  12.831746031746013
# dataset_error =  9
# #####################################
# No license plate detected.
# row =  0X65AWD
# count =  12.831746031746013
# dataset_error =  9
# #####################################
# 1/1 [==============================] - 0s 22ms/step
# predicted number =  M
# row =  0PECL0L
# count =  12.831746031746013
# dataset_error =  9
# #####################################
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# predicted number =  W88
# row =  HR26BR9044
# count =  12.831746031746013
# dataset_error =  9
# #####################################
# No license plate detected.
# row =  AP29BP585
# count =  12.831746031746013
# dataset_error =  9
# #####################################
# count =  12.831746031746013
# dataset_error =  10
# #####################################
# No license plate detected.
# row =  1268
# count =  12.831746031746013
# dataset_error =  10
# #####################################
# No license plate detected.
# row =  L19TLC
# count =  12.831746031746013
# dataset_error =  10
# #####################################
# No license plate detected.
# row =  M17108 FV1232
# count =  12.831746031746013
# dataset_error =  10
# #####################################
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# predicted number =  R8RM5
# row =  U15474
# count =  12.998412698412679
# dataset_error =  10
# #####################################
# count =  12.998412698412679
# dataset_error =  11
# #####################################
# No license plate detected.
# row =  TN02BL9
# count =  12.998412698412679
# dataset_error =  11
# #####################################
# count =  12.998412698412679
# dataset_error =  12
# #####################################
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# predicted number =  8MAE
# row =  CH01AN0001
# count =  13.098412698412679
# dataset_error =  12
# #####################################
# count =  13.098412698412679
# dataset_error =  13
# #####################################
# No license plate detected.
# row =  F1
# count =  13.098412698412679
# dataset_error =  13
# #####################################
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# predicted number =  XE88
# row =  FU3348 NZ1017
# count =  13.252258852258832
# dataset_error =  13
# #####################################
# No license plate detected.
# row =  PEN15
# count =  13.252258852258832
# dataset_error =  13
# #####################################
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# predicted number =  8MAE
# row =  CH01AN0001
# count =  13.352258852258831
# dataset_error =  13
# #####################################
# count =  13.352258852258831
# dataset_error =  14
# #####################################
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# predicted number =  MWSRS8EBMM5888
# row =  KL01CA2555
# count =  13.452258852258831
# dataset_error =  14
# #####################################
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# predicted number =  SCS8K8EUM
# row =  MH01BB550
# count =  13.563369963369942
# dataset_error =  14
# #####################################
# No license plate detected.
# row =  7VIG263
# count =  13.563369963369942
# dataset_error =  14
# #####################################
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# predicted number =  S88X488
# row =  DL8CX4850
# count =  14.230036630036606
# dataset_error =  14
# #####################################
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# predicted number =  89B088862
# row =  DL3CBD5092
# count =  14.630036630036605
# dataset_error =  14
# #####################################
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# predicted number =  BE488WA8KK48WW
# row =  DL49AK39
# count =  15.255036630036605
# dataset_error =  14
# #####################################
# No license plate detected.
# row =  MH20BQ20
# count =  15.255036630036605
# dataset_error =  14
# #####################################
# No license plate detected.
# row =  KA09MA2662
# count =  15.255036630036605
# dataset_error =  14
# #####################################
# No license plate detected.
# row =  MCB025
# count =  15.255036630036605
# dataset_error =  14
# #####################################
# No license plate detected.
# row =  PRIVATE
# count =  15.255036630036605
# dataset_error =  14
# #####################################
# predicted number =
# row =  PTB557K
# count =  15.255036630036605
# dataset_error =  14
# #####################################
# No license plate detected.
# row =  695299
# count =  15.255036630036605
# dataset_error =  14
# #####################################
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# predicted number =  EM2WSXMMW8RKW
# row =  DL7CN5617
# count =  15.255036630036605
# dataset_error =  14
# #####################################
# No license plate detected.
# row =  0007PLATECOM
# count =  15.255036630036605
# dataset_error =  14
# #####################################
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# predicted number =  ESY8S
# row =  M666YOB
# count =  15.397893772893747
# dataset_error =  14
# #####################################
# No license plate detected.
# row =  MH01BB5992
# count =  15.397893772893747
# dataset_error =  14
# #####################################
# No license plate detected.
# row =  LR33TEE
# count =  15.397893772893747
# dataset_error =  14
# #####################################
# No license plate detected.
# row =  GT
# count =  15.397893772893747
# dataset_error =  14
# #####################################
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# predicted number =  RRGERR8R88W6R
# row =  TN21AU1153
# count =  15.397893772893747
# dataset_error =  14
# #####################################
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# predicted number =  XG8SXG
# row =  IMACAR
# count =  15.397893772893747
# dataset_error =  14
# #####################################
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# predicted number =  8LKK8H888S8E
# row =  15LK10898
# count =  16.397893772893745
# dataset_error =  14
# #####################################
# No license plate detected.
# row =  2222
# count =  16.397893772893745
# dataset_error =  14
# #####################################
# No license plate detected.
# row =  PRIVATE
# count =  16.397893772893745
# dataset_error =  14
# #####################################
# No license plate detected.
# row =  983
# count =  16.397893772893745
# dataset_error =  14
# #####################################
# No license plate detected.
# row =  BJR216
# count =  16.397893772893745
# dataset_error =  14
# #####################################
# No license plate detected.
# row =  UK17C09
# count =  16.397893772893745
# dataset_error =  14
# #####################################
# No license plate detected.
# row =  WMY9051
# count =  16.397893772893745
# dataset_error =  14
# #####################################
# count =  16.397893772893745
# dataset_error =  15
# #####################################
# predicted number =
# row =  DL1N4268
# count =  16.397893772893745
# dataset_error =  15
# #####################################
# No license plate detected.
# row =  EV09FTW
# count =  16.397893772893745
# dataset_error =  15
# #####################################
# No license plate detected.
# row =  GOOD
# count =  16.397893772893745
# dataset_error =  15
# #####################################
# No license plate detected.
# row =  52292Z
# count =  16.397893772893745
# dataset_error =  15
# #####################################
# No license plate detected.
# row =  4SZW590
# count =  16.397893772893745
# dataset_error =  15
# #####################################
# No license plate detected.
# row =  MPEACHW
# count =  16.397893772893745
# dataset_error =  15
# #####################################
# No license plate detected.
# row =  JHIIHAD
# count =  16.397893772893745
# dataset_error =  15
# #####################################
# No license plate detected.
# row =  V12LAF
# count =  16.397893772893745
# dataset_error =  15
# #####################################
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# predicted number =  BEWY8X8X8SE
# row =  BRIT0001
# count =  16.522893772893745
# dataset_error =  15
# #####################################
# No license plate detected.
# row =  SWIFT
# count =  16.522893772893745
# dataset_error =  15
# #####################################
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# ...
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# predicted number =  8MAE
# row =  CH01AN0001
# count =  35.46661671661679
# dataset_error =  28
# #####################################
# No license plate detected.
# row =  E2O
# count =  35.46661671661679
# dataset_error =  28
# #####################################
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# predicted number =  MB8E2SESEMM88S
# row =  HR26CE1485
# count =  36.1666167166168
# dataset_error =  28
# #####################################
# No license plate detected.
# row =  TN21BC6225
# count =  36.1666167166168
# dataset_error =  28
# #####################################
# No license plate detected.
# row =  S7JDW
# count =  36.1666167166168
# dataset_error =  28
# #####################################
# count =  36.1666167166168
# dataset_error =  29
# #####################################
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# predicted number =  8M2E22288MMMK
# row =  B2229HM
# count =  37.30947385947397
# dataset_error =  29
# #####################################
# No license plate detected.
# row =  BYHM136
# count =  37.30947385947397
# dataset_error =  29
# #####################################
# predicted number =
# row =  4141
# count =  37.30947385947397
# dataset_error =  29
# #####################################
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# predicted number =  8H2M3E8M
# row =  MH14GN9239
# count =  37.809473859473975
# dataset_error =  29
# #####################################
# No license plate detected.
# row =  W718AX
# count =  37.809473859473975
# dataset_error =  29
# #####################################
# No license plate detected.
# row =  2089563
# count =  37.809473859473975
# dataset_error =  29
# #####################################
# No license plate detected.
# row =  CRAIG
# count =  37.809473859473975
# dataset_error =  29
# #####################################
# No license plate detected.
# row =  YA55D
# count =  37.809473859473975
# dataset_error =  29
# #####################################
# No license plate detected.
# row =  DX103
# count =  37.809473859473975
# dataset_error =  29
# #####################################
# No license plate detected.
# row =  EV09FTW
# count =  37.809473859473975
# dataset_error =  29
# #####################################
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# predicted number =  AB6488
# row =  AB44887
# count =  38.523759573759705
# dataset_error =  29
# #####################################
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# predicted number =  M8AMM8M8
# row =  HR26AZ5927
# count =  38.623759573759706
# dataset_error =  29
# #####################################
# No license plate detected.
# row =  32
# count =  38.623759573759706
# dataset_error =  29
# #####################################
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# predicted number =  AB6488
# row =  AB44887
# count =  39.338045288045436
# dataset_error =  29
# #####################################
# No license plate detected.
# row =  5H798 5H799
# count =  39.338045288045436
# dataset_error =  29
# #####################################
# No license plate detected.
# row =  BKWL324
# count =  39.338045288045436
# dataset_error =  29
# #####################################
# No license plate detected.
# row =  DZVG49
# count =  39.338045288045436
# dataset_error =  29
# #####################################
# No license plate detected.
# row =  M771276
# count =  39.338045288045436
# dataset_error =  29
# #####################################
# No license plate detected.
# row =  MH12MR0613
# count =  39.338045288045436
# dataset_error =  29
# #####################################
# No license plate detected.
# row =  1CYAH8N
# count =  39.338045288045436
# dataset_error =  29
# #####################################
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# predicted number =  EK8P3E
# row =  REAP3R
# count =  40.00471195471209
# dataset_error =  29
# #####################################
# No license plate detected.
# row =  9214
# count =  40.00471195471209
# dataset_error =  29
# #####################################
# predicted number =
# row =  MMN306
# count =  40.00471195471209
# dataset_error =  29
# #####################################
# No license plate detected.
# row =  0X65AWD
# count =  40.00471195471209
# dataset_error =  29
# #####################################
# No license plate detected.
# row =  889VSM
# count =  40.00471195471209
# dataset_error =  29
# #####################################
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# predicted number =  KR
# row =  HR26BC5514
# count =  40.104711954712094
# dataset_error =  29
# #####################################
# No license plate detected.
# row =  SGQ51U SGQ51U
# count =  40.104711954712094
# dataset_error =  29
# #####################################
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# predicted number =  G6
# row =  066RAF 067RAF
# count =  40.181635031635174
# dataset_error =  29
# #####################################
# No license plate detected.
# row =  BMW
# count =  40.181635031635174
# dataset_error =  29
# #####################################
# 1/1 [==============================] - 0s 22ms/step
# predicted number =  R
# row =  MH14LC3687
# count =  40.181635031635174
# dataset_error =  29
# #####################################
# No license plate detected.
# row =  1268
# count =  40.181635031635174
# dataset_error =  29
# #####################################
# No license plate detected.
# row =  PETES
# count =  40.181635031635174
# dataset_error =  29
# #####################################
# count =  40.181635031635174
# dataset_error =  30
# #####################################
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# predicted number =  BBEM8SPWYY
# row =  RK977AF
# count =  40.181635031635174
# dataset_error =  30
# #####################################
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# predicted number =  GS
# row =  EWWP00P
# count =  40.181635031635174
# dataset_error =  30
# #####################################
# No license plate detected.
# row =  VIPER
# count =  40.181635031635174
# dataset_error =  30
# #####################################
# No license plate detected.
# row =  LR33TEE
# count =  40.181635031635174
# dataset_error =  30
# #####################################
# No license plate detected.
# row =  6431 8544
# count =  40.181635031635174
# dataset_error =  30
# #####################################
# No license plate detected.
# row =  DRUNK
# count =  40.181635031635174
# dataset_error =  30
# #####################################
# predicted number =
# row =  MH12NE8922
# count =  40.181635031635174
# dataset_error =  30
# #####################################
# No license plate detected.
# row =  172TMJ
# count =  40.181635031635174
# dataset_error =  30
# #####################################
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# predicted number =  BBMMRSEM8BR
# row =  BAD231
# count =  40.68163503163517
# dataset_error =  30
# #####################################
# No license plate detected.
# row =  0X65AWD
# count =  40.68163503163517
# dataset_error =  30
# #####################################
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 42ms/step
# predicted number =  8H2M3E8M
# row =  MH14GN9239
# count =  41.181635031635174
# dataset_error =  30
# #####################################
# No license plate detected.
# row =  SKIPGAS
# count =  41.181635031635174
# dataset_error =  30
# #####################################
# count =  41.181635031635174
# dataset_error =  31
# #####################################
# predicted number =
# row =  MH20EE7596
# count =  41.181635031635174
# dataset_error =  31
# #####################################
# No license plate detected.
# row =  P3RVP
# count =  41.181635031635174
# dataset_error =  31
# #####################################
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# predicted number =  88M22WW8W4
# row =  KA03MG2784
# count =  41.881635031635184
# dataset_error =  31
# #####################################
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# predicted number =  SMSM2MEMEXMMMMS
# row =  G526JHD
# count =  42.02449217449233
# dataset_error =  31
# #####################################
# No license plate detected.
# row =  CRAIG
# count =  42.02449217449233
# dataset_error =  31
# #####################################
# No license plate detected.
# row =  01CC1A0001
# count =  42.02449217449233
# dataset_error =  31
# #####################################
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# predicted number =  8WGEW8VWWWXX88
# row =  DZ1YXR
# count =  42.35782550782566
# dataset_error =  31
# #####################################
# No license plate detected.
# row =  KA1SER
# count =  42.35782550782566
# dataset_error =  31
# #####################################
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# predicted number =  E8
# row =  BCG986
# count =  42.52449217449232
# dataset_error =  31
# #####################################
# No license plate detected.
# row =  KLBOSS
# count =  42.52449217449232
# dataset_error =  31
# #####################################
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# predicted number =  BE488WA8KK48WW
# row =  DL49AK49
# count =  43.14949217449232
# dataset_error =  31
# #####################################

# %%
print("Total count = ", count)
valid_dataset = len(sorted_files) - dataset_error
print("Total valid dataset = ", valid_dataset)
print("Accuracy: "+str((count/valid_dataset)*100)+"%")
# Out:
# Total count =  43.14949217449232
# Total valid dataset =  402
# Accuracy: 10.73370452101799%
